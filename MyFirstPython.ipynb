# %% [markdown]
# <a href="https://colab.research.google.com/github/nkbugalia/LearnAI/blob/main/MyFirstPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello AI! 🚀 My journey starts here.")
# Out:
# Hello AI! 🚀 My journey starts here.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("My First Plot in Colab")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Sample data (study hours vs scores)
X = np.array([[1],[2],[3],[4],[5]])
y = np.array([30, 50, 65, 80, 90])

model = LinearRegression()
model.fit(X, y)

# Predict score for 6 hours of study
pred = model.predict([[6]])
print(f"Predicted score for 6 hrs study: {pred[0]:.2f}")
# Out:
# Predicted score for 6 hrs study: 108.00
